# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravanikuldharan/Blogverse/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("students_dataset.csv")

df.head()
# Out:
#     Name  Age  Marks    City
# 0   Amit   22     78  Mumbai
# 1  Priya   23     85    Pune
# 2  Rahul   21     67   Delhi
# 3  Sneha   24     90  Mumbai
# 4  Karan   22     72   Delhi

# %%
df.tail()
# Out:
#     Name  Age  Marks    City
# 3  Sneha   24     90  Mumbai
# 4  Karan   22     72   Delhi
# 5   Neha   23     88    Pune
# 6   Ravi   25     60  Mumbai
# 7  Pooja   21     79   Delhi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      int64
#  2   Marks   8 non-null      int64
#  3   City    8 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 388.0+ bytes

# %%
df.describe()
# Out:
#              Age     Marks
# count   8.000000   8.00000
# mean   22.625000  77.37500
# std     1.407886  10.50085
# min    21.000000  60.00000
# 25%    21.750000  70.75000
# 50%    22.500000  78.50000
# 75%    23.250000  85.75000
# max    25.000000  90.00000
